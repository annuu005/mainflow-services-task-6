# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the webpage
urls = "https://realpython.com/" 
result = requests.get(urls)

# Extract all images from the webpage 
image = []
for img in soup.find_all('img'): 
    image.append(img.get('src'))
print("Images:\n")
for img in image:
    print(img)

# Parse the HTML content using BeautifulSoup 
soup=BeautifulSoup(result.content, 'html.parser')

# Extract text from the page 
text=soup.get_text(separator=' ', strip=True) 
print("Text:",text)

# Extract all Links from the webpage 
links = [] 
for link in soup.find_all('a'): 
    links.append(link.get('href')) 
print("Links:") 
for link in links:
    print(link)
    
# Extract the title of the webpage 
title=soup.find('title').text if soup.find('title') else 'No title found' 
print("Title:", title)
# Out:
# Images:
#
# /static/real-python-logo.893c30edea53.svg
# https://files.realpython.com/media/unittest.mock-Tutorial_Watermarked.8e92b54478af.jpg
# /static/pytrick-dict-merge.4201a0125a5e.png
# https://files.realpython.com/media/Building-a-Python-Calculator-With-PyQt_Watermarked.e4c1a5cf2018.jpg
# https://files.realpython.com/media/Creating-Good-README.md-Files-for-Your-Python-Projects_Watermarked.034ab572fa3e.jpg
# https://files.realpython.com/media/Build-a-Guitar-Synthesizer-with-Python_Watermarked.a80fc2b14da2.jpg
# https://files.realpython.com/media/How-to-Round-Numbers-in-Python_Watermark.6fb8573ce8f5.jpg
# https://files.realpython.com/media/Showcase-Ruff-Linter_Watermarked.71e600eb11de.jpg
# https://files.realpython.com/media/Python-Mappings_Watermarked-2.a8cbbb3a0c5d.jpg
# https://files.realpython.com/media/How-to-List-Get-All-Files-in-a-Directory-with-Python_Watermarked.b31aa29fe7c7.jpg
# https://files.realpython.com/media/Monthly-Python-News_Purple_Watermarked.5b2e306328cb.jpg
# https://files.realpython.com/media/Python-String-Formatting-Best-Practices_Watermarked-2.e0a560b0184d.jpg
# https://files.realpython.com/media/Interfaces-in-Python_Watermarked.f9ce5bda238c.jpg
# https://files.realpython.com/media/String-Interpolation-in-Python_Watermarked.71ef9704414a.jpg
# https://files.realpython.com/media/What-Are-CRUD-Operations_Watermarked.b243ab2b79cb.jpg
# https://files.realpython.com/media/Iterators-and-Iterables-in-Python-What-Are-They-and-How-to-Use-Them_Watermarked.5df74332ac58.jpg
# https://files.realpython.com/media/Pandas-Pivot-Table-Aggregate-Data-in-Python_Watermarked.b50d3e60cb29.jpg
# https://files.realpython.com/media/Python-calendar_Watermarked.f1a5c21b8fa3.jpg
# https://files.realpython.com/media/Python-GUI-Programming-With-Tkinter_Watermarked.9e1a9c9070e4.jpg
# https://files.realpython.com/media/Basic-Data-Types-in-Python_Watermarked.e3dd34457952.jpg
# https://files.realpython.com/media/Pythons-Built-in-Exceptions-A-Walkthrough-With-Examples_Watermarked.c11d5d8176c3.jpg
# https://www.facebook.com/tr?id=2220911568135371&ev=PageView&noscript=1
# Text: Python Tutorials – Real Python Start Here Learn Python Python Tutorials → In-depth articles and video courses Learning Paths → Guided study plans for accelerated learning Quizzes → Check your learning progress Browse Topics → Focus on a specific area or skill level Community Chat → Learn with other Pythonistas Office Hours → Live Q&A calls with Python experts Podcast → Hear what’s new in the world of Python Books → Round out your knowledge and learn offline Unlock All Content → More Learner Stories Python Newsletter Python Job Board Meet the Team Become a Tutorial Writer Become a Video Instructor Search / Join Sign‑In Real Python Tutorials NEW Understanding the Python Mock Object Library In this tutorial, you'll learn how to use the Python mock object library, unittest.mock, to create and use mock objects to improve your tests. Obstacles like complex logic and unpredictable dependencies make writing valuable tests difficult, but unittest.mock can help you overcome these obstacles. Jun 26, 2024 intermediate testing — FREE Email Series — 🐍 Python Tricks 💌 Get Python Tricks » 🔒 No spam. Unsubscribe any time. Browse Topics Guided Learning Paths Basics Intermediate Advanced api best-practices career community databases data-science data-structures data-viz devops django docker editors flask front-end gamedev gui machine-learning numpy projects python testing tools web-dev web-scraping Explore Real Python Learning Paths Guided study plans for accelerated learning Python Tutorials In-depth articles and step-by-step video courses Quizzes Evaluate your Python knowledge with quick tests Browse Topics Focus on a specific area or skill level Community Chat Learn with other Pythonistas Office Hours Live Q&A calls with experts from Real Python Podcast Hear what’s new in the world of Python Books Round out your knowledge and learn offline Search » New Releases View All » Build a GUI Calculator With PyQt and Python Jun 25, 2024 intermediate gui projects Creating Great README Files for Your Python Projects Jun 24, 2024 basics best-practices projects Build a Guitar Synthesizer: Play Musical Tablature in Python Jun 19, 2024 intermediate projects Rounding Numbers in Python Jun 18, 2024 intermediate best-practices python Ruff: A Modern Python Linter for Error-Free and Maintainable Code Jun 17, 2024 intermediate devops tools Python Mappings: A Comprehensive Guide Jun 12, 2024 intermediate python Remove ads Listing All Files in a Directory With Python Jun 11, 2024 intermediate Python News: What's New From May 2024 Jun 10, 2024 community Python String Formatting: Available Tools and Their Features Jun 05, 2024 basics best-practices python Python Interfaces: Object-Oriented Design Principles Jun 04, 2024 advanced python String Interpolation in Python: Exploring Available Tools Jun 03, 2024 basics best-practices python What Are CRUD Operations? May 29, 2024 intermediate api databases web-dev Efficient Iterations With Python Iterators and Iterables May 28, 2024 intermediate python How to Create Pivot Tables With pandas May 27, 2024 intermediate data-science data-viz The Python calendar Module: Create Calendars With Python May 22, 2024 intermediate Building a Python GUI Application With Tkinter May 21, 2024 basics gui Basic Data Types in Python: A Quick Exploration May 20, 2024 basics python Python's Built-in Exceptions: A Walkthrough With Examples May 15, 2024 intermediate python Load More Search » Remove ads © 2012–2024 Real Python ⋅ Newsletter ⋅ Podcast ⋅ YouTube ⋅ Twitter ⋅ Facebook ⋅ Instagram ⋅ Python Tutorials ⋅ Search ⋅ Privacy Policy ⋅ Energy Policy ⋅ Advertise ⋅ Contact Happy Pythoning!
# Links:
# /
# /start-here/
# #
# /search?kind=article&kind=course&order=newest
# /learning-paths/
# /quizzes/
# /tutorials/all/
# /community/
# /office-hours/
# /podcasts/rpp/
# /products/books/
# /account/join/
# #
# /learner-stories/
# /newsletter/
# https://www.pythonjobshq.com
# /team/
# /write-for-us/
# /become-an-instructor/
# /search
# /search
# /account/join/
# /account/login/?next=%2F
# /python-mock-library/
# /python-mock-library/
# /tutorials/intermediate/
# /tutorials/testing/
# /tutorials/all/
# /learning-paths/
# /search?level=basics
# /search?level=intermediate
# /search?level=advanced
# /tutorials/api/
# /tutorials/best-practices/
# /tutorials/career/
# /tutorials/community/
# /tutorials/databases/
# /tutorials/data-science/
# /tutorials/data-structures/
# /tutorials/data-viz/
# /tutorials/devops/
# /tutorials/django/
# /tutorials/docker/
# /tutorials/editors/
# /tutorials/flask/
# /tutorials/front-end/
# /tutorials/gamedev/
# /tutorials/gui/
# /tutorials/machine-learning/
# /tutorials/numpy/
# /tutorials/projects/
# /tutorials/python/
# /tutorials/testing/
# /tutorials/tools/
# /tutorials/web-dev/
# /tutorials/web-scraping/
# /learning-paths/
# /search?kind=article&kind=course&order=newest
# /quizzes/
# /tutorials/all/
# /community/
# /office-hours/
# /podcasts/rpp/
# /products/books/
# /search
# /search?order=newest
# /search?order=newest
# /courses/build-gui-calculator-pyqt/
# /courses/build-gui-calculator-pyqt/
# /tutorials/intermediate/
# /tutorials/gui/
# /tutorials/projects/
# /readme-python-project/
# /readme-python-project/
# /tutorials/basics/
# /tutorials/best-practices/
# /tutorials/projects/
# /python-guitar-synthesizer/
# /python-guitar-synthesizer/
# /tutorials/intermediate/
# /tutorials/projects/
# /courses/rounding-numbers-python/
# /courses/rounding-numbers-python/
# /tutorials/intermediate/
# /tutorials/best-practices/
# /tutorials/python/
# /ruff-python/
# /ruff-python/
# /tutorials/intermediate/
# /tutorials/devops/
# /tutorials/tools/
# /python-mappings/
# /python-mappings/
# /tutorials/intermediate/
# /tutorials/python/
# /account/join/
# /courses/listing-all-files-directory/
# /courses/listing-all-files-directory/
# /tutorials/intermediate/
# /python-news-may-2024/
# /python-news-may-2024/
# /tutorials/community/
# /python-string-formatting/
# /python-string-formatting/
# /tutorials/basics/
# /tutorials/best-practices/
# /tutorials/python/
# /courses/interfaces-object-oriented-design-principles/
# /courses/interfaces-object-oriented-design-principles/
# /tutorials/advanced/
# /tutorials/python/
# /python-string-interpolation/
# /python-string-interpolation/
# /tutorials/basics/
# /tutorials/best-practices/
# /tutorials/python/
# /crud-operations/
# /crud-operations/
# /tutorials/intermediate/
# /tutorials/api/
# /tutorials/databases/
# /tutorials/web-dev/
# /courses/efficient-iterations-iterators-iterables/
# /courses/efficient-iterations-iterators-iterables/
# /tutorials/intermediate/
# /tutorials/python/
# /how-to-pandas-pivot-table/
# /how-to-pandas-pivot-table/
# /tutorials/intermediate/
# /tutorials/data-science/
# /tutorials/data-viz/
# /python-calendar-module/
# /python-calendar-module/
# /tutorials/intermediate/
# /courses/building-gui-application-tkinter/
# /courses/building-gui-application-tkinter/
# /tutorials/basics/
# /tutorials/gui/
# /python-data-types/
# /python-data-types/
# /tutorials/basics/
# /tutorials/python/
# /python-built-in-exceptions/
# /python-built-in-exceptions/
# /tutorials/intermediate/
# /tutorials/python/
# /search
# /account/join/
# /newsletter/
# /podcasts/rpp/
# https://www.youtube.com/realpython
# https://twitter.com/realpython
# https://facebook.com/LearnRealPython
# https://www.instagram.com/realpython/
# /
# /search
# /privacy-policy/
# /energy-policy/
# /sponsorships/
# /contact/
# Title: Python Tutorials – Real Python
